# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import os
from pandas import DataFrame 
from IPython.display import display, HTML
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all" #setta l'esecuzione di più statement in unica cella

pd.set_option('display.max_colwidth', -1) 
pd.set_option('display.width', 5000) 
pd.set_option('display.max_columns', 100) 
# Set up formatting so larger numbers aren't displayed in scientific notation (h/t @thecapacity)
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
#carico i cup
cup = pd.read_csv("data/CUP.csv", sep='|',encoding='iso-8859-1',  error_bad_lines=False, warn_bad_lines=True)
# Out:
# b'Skipping line 1907: expected 73 fields, saw 118\n'
# b'Skipping line 38483: expected 73 fields, saw 138\n'
# b'Skipping line 57886: expected 73 fields, saw 118\nSkipping line 62887: expected 73 fields, saw 118\n'
# b'Skipping line 68501: expected 73 fields, saw 138\nSkipping line 71900: expected 73 fields, saw 138\n'
# b'Skipping line 78493: expected 73 fields, saw 138\n'
# b'Skipping line 87767: expected 73 fields, saw 138\n'
# b'Skipping line 94426: expected 73 fields, saw 138\nSkipping line 96031: expected 73 fields, saw 119\n'
# b'Skipping line 110129: expected 73 fields, saw 120\n'
# b'Skipping line 116684: expected 73 fields, saw 138\nSkipping line 121471: expected 73 fields, saw 118\n'
# b'Skipping line 140739: expected 73 fields, saw 137\nSkipping line 145387: expected 73 fields, saw 118\n'
# b'Skipping line 147635: expected 73 fields, saw 138\nSkipping line 148836: expected 73 fields, saw 118\n'
# b'Skipping line 156680: expected 73 fields, saw 118\n'
# ...

# %%
cup.loc[cup['CUP']=='I21E15000200005']
# Out:
#                     CUP                                                                                                                                                                              DESCRIZIONE_SINTETICA_CUP ANNO_DECISIONE STATO_PROGETTO COSTO_PROGETTO FINANZIAMENTO_PROGETTO CODICE_STATO   STATO CODICE_AREA_GEOGRAFICA AREA_GEOGRAFICA  CODICE_REGIONE   REGIONE CODICE_PROVINCIA SIGLA_PROVINCIA PROVINCIA  CODICE_COMUNE         COMUNE PIVA_CODFISCALE_SOG_TITOLARE               SOGGETTO_TITOLARE INDIRIZZO_SOG_TITOLARE TIPO_INDIRIZZO_SOG_TITOLARE NUM_CIVICO_SOG_TITOLARE LOCALITA_SOG_TITOLARE CAP_SOGGETTO_TITOLARE COMUNE_SOGGETTO_TITOLARE CODICE_COMUNE_SOGG_TITOLARE CODICE_SOTTOCATEG_SOGGETTO   SOTTOCATEGORIA_SOGGETTO  CODICE_CATEGORIA_SOGGETTO                                     CATEGORIA_SOGGETTO CODICE_AREA_SOGGETTO           AREA_SOGGETTO  CODICE_NATURA_INTERVENTO                                          NATURA_INTERVENTO  CODICE_TIPO_INTERVENTO                           
# ...

# %%
data = pd.read_csv("edifici_6_cn_cantieri_cup.csv", sep='|', header=0,  encoding='utf-8',converters={'CODICEEDIFICIO': lambda x: str(x)})
#esempio di filtro su dati
# lo stesso codice CUP appartiene a scuole

data.loc[data['CUP']=='I21E15000200005']
# Out:
#     AREAGEOGRAFICA CODICECOMUNESCUOLA CODICEISTITUTORIFERIMENTO CODICESCUOLA DENOMINAZIONESCUOLA DESCRIZIONECOMUNE DESCRIZIONETIPOLOGIAGRADOISTRUZIONESCUOLA   INDIRIZZOSCUOLA PROVINCIA   REGIONE CODICEEDIFICIO SIGLAPROVINCIA STATOEDIFICIO VINCOLIIDROGEOLOGICI VINCOLIPAESAGGIO EDIFICIOVETUSTO             VINCOLIZONASISMICA PROGETTAZIONEANTISISMICA USOSCOLASTICO ALTRIUSI ANNOCOSTRUZIONE  FASCIAETACOSTRUZIONE ANNOADATTAMENTO  FASCIAETAADATTAMENTO  NUMEROPIANI SPERFICIEAREATOTALE SPERFICIEAREALIBERA    VOLUME SPAZIDIDATTICI AULAMAGNA   MENSA PALESTRAPISCINA SPAZIAMMINISTRATIVI SCUOLABUS TRASPORTIPUBBLICIURBANI TRASPORTIPUBBLICIINTERURBANI TRASPORTIFERROVIARI MEZZIPRIVATI TRASPORTODISABILI                                                            Linea_finanziamento         COMUNE FONTE Data_aggiornamento_lavori Data_inizio   Data_fine ENTE_RICHIEDENTE TIPOLOGIA_ENTE_RICHIEDENTE   COD_PRINC OGGETTO_INTERVENTO INFO_AGGIUNTIVE  LATITUDINE  LONGITUDINE             TIPO_INTERVENTO     STATO 
# ...
