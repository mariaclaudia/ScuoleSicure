# %% [markdown]
# # Scuole Sicure
# ## Il patrimonio scolastico in Italia
#
#
# ### Analisi tra differenti basi di dati e soggetti

# %% [markdown]
# ## Attori coinvolti:
#
# ### OpenCUP:
#
# http://opencup.gov.it
#
#
# Il **Codice Unico Progetto (CUP)** è il “codice fiscale” di un progetto, una stringa alfanumerica di 15 caratteri che identifica univocamente un progetto di investimento pubblico finanziato con risorse pubbliche o private.
#
# Open CUP mette a disposizione di tutti - cittadini, istituzioni ed altri enti - i dati, in formato aperto, sulle decisioni di investimento pubblico finanziate con fondi pubblici nazionali, comunitari o regionali o con risorse private registrate con il Codice Unico di Progetto.
#
# Importanza nei processi decisionali e di monitoraggio degli stakeholder pubblici e provati
#
# Importanza di integrazione tra i dati di diversi stake holder istituzionali
#
#
# Dati aggiornati al: 01-01-2018
#
# Licenza: Creative Commons 4.0 Attribuzione (CC BY 4.0)
#
# Presenti su DAF:
# econ__policy.default_org_o_cup
#
# ### Italia Sicura - Cantiere scuola
#
# L'edilizia scolastica  è tra le priorità dell'azione di Governo. Per questo è stata creata una struttura di Missione che assicura il coordinamento tra diversi Ministeri e garantisce l'impulso e il coordinamento di varie linee di finanziamento e il sostegno agli Enti locali, che operano nella gestione diretta delle scuole.
#
# I protagonisti di questa grande opera di riqualificazione del patrimonio scolastico italiano (oltre 40.000 scuole sparse sul territorio nazionale) sono coloro che la scuola la vivono ogni giorno: insegnanti e alunni
#
# Referente: Laura Galimberti - Coordinatrice Struttura missione scuola (PCM)
#
# https://www.youtube.com/playlist?list=PLweUe9F1xe4uDLngGc9hwOiZBsnn062Dk
#
# http://italiasicura.governo.it/site/home/scuole.html
#
# Link correlati:
# http://www.istruzione.it/edilizia_scolastica/anagrafe.shtml
#
# Italiasicura per gli interventi di edilizia straordinaria
# http://italiasicura.governo.it/site/home/italiasicura.html
#
# http://italiasicura.governo.it/site/home/scuole.html
#
# * [Cantieri Scuole](http://www.cantieriscuole.it)
#
# * [OpenCoesione per i progetti finanziati dalle politiche di coesione](http://www.opencoesione.gov.it/)
#
# * [OpenCantieri dedicato ai lavori di infrastruttura pubblica](http://opencantieri.mit.gov.it/)
#
#
# Tutti i finanziamenti STATALI, non altri enti e fondazioni.
# Il codice edificio scolastico deve essere campo.
# Dal 2014 il monitoraggio è vero.
# http://www.cantieriscuole.it/open_data.aspx
#
#
# * [#SBLOCCASCUOLE 2016 - DPCM 27 aprile 2016](http://www.cantieriscuole.it/open_data.aspx?id=27&tipo=csv)
# * [#SBLOCCASCUOLE 2017 - DM 26 aprile 2017](http://www.cantieriscuole.it/open_data.aspx?id=40&tipo=csv)
# * [#Scuole Nuove - Sblocco Patto Comuni 2014-2015 - D.L. 66/2014 art. 48 c. 1](http://www.cantieriscuole.it/open_data.aspx?id=25&tipo=csv)
# * [#Scuole Nuove - Sblocco Patto Province / Città Metropolitane 2015 - L. 190/2014 art. 1 c. 467](http://www.cantieriscuole.it/open_data.aspx?id=26&tipo=csv)
# * [#Scuole Sicure - CIPE 30/06/2014](http://www.cantieriscuole.it/open_data.aspx?id=31&tipo=csv)
# * [#Scuole Sicure - D.L. 69/2013](http://www.cantieriscuole.it/open_data.aspx?id=2&tipo=csv)
# * [6000 Campanili - D.L. 69/2013 - L. 164/2014](http://www.cantieriscuole.it/open_data.aspx?id=22&tipo=csv)
# * [Adeguamento Sismico - Dipartimento Protezione Civile - D.L. 269 30 settembre 2003 art. 32 bis](http://www.cantieriscuole.it/open_data.aspx?id=3&tipo=csv)
# * [Adeguamento sismico – DL 269/2003 art. 32 bis – DM 943/2015](http://www.cantieriscuole.it/open_data.aspx?id=50&tipo=csv)
# * [Alluvione Sardegna - Legge n.190 23/12/2014 - Art.1 comma 152](http://www.cantieriscuole.it/open_data.aspx?id=43&tipo=csv)
# * [Cantieri in Comune - Delibera CIPE 38/2015](http://www.cantieriscuole.it/open_data.aspx?id=23&tipo=csv)
# * [Commissario Straordinario Ricostruzione Sisma 2016 - Ordinanza n. 14 del 31 gennaio 2017](http://www.cantieriscuole.it/open_data.aspx?id=48&tipo=csv)
# * [Decreto Mutui BEI prima annualità - Decreto Interministeriale 23 gennaio 2015](http://www.cantieriscuole.it/open_data.aspx?id=24&tipo=csv)
# * [Decreto Mutui BEI seconda annualità - Decreto Interministeriale n. 390 del 6 giugno 2017](http://www.cantieriscuole.it/open_data.aspx?id=49&tipo=csv)
# * [Fondo Kyoto - D.L. 91/2014](http://www.cantieriscuole.it/open_data.aspx?id=14&tipo=csv)
# * [Messa in sicurezza elementi non strutturali - Delibere CIPE 32/2010 e 6/2012](http://www.cantieriscuole.it/open_data.aspx?id=5&tipo=csv)
# * [PATTI PER IL SUD – FSC 2014-2020 – Delibera CIPE n.26 del 10/08/16](http://www.cantieriscuole.it/open_data.aspx?id=38&tipo=csv) --> ATTENZIONE, per ora escluso, errore EOF
# * [Periferie - Legge n.208 del 28/12/2015](http://www.cantieriscuole.it/open_data.aspx?id=32&tipo=csv)
# * [POI - Energie Rinnovabili - D.M. 24 aprile 2015](http://www.cantieriscuole.it/open_data.aspx?id=4&tipo=csv)
# * [PON/POR - Fondi Strutturali 2007/2013](http://www.cantieriscuole.it/open_data.aspx?id=6&tipo=csv)
# * [Quota statale 8 x 1000 IRPEF per l'edilizia scolastica - Legge 147, art. 1 comma 296](http://www.cantieriscuole.it/open_data.aspx?id=41&tipo=csv)
# * [Scuole d'Abruzzo - Il Futuro in Sicurezza - Delibere CIPE 47/2009, 83/2013, 77/2015](http://www.cantieriscuole.it/open_data.aspx?id=28&tipo=csv)
#
# ### MIUR - Dataset su edifici scolastici e alunni:
#
# Data pubblicazione:	09/03/2017
# Dati al:	31/08/2016 - 201516
#
# http://dati.istruzione.it/opendata/opendata/catalogo/elements1/leaf/?datasetId=DS0200EDIANAGRAFESTA
#
#
# http://dati.ustat.miur.it/dataset/07d1c63f-9b1a-47f0-9648-66663e59c3f6/resource/9bebad94-3c0b-469e-8e50-b474d52aeb27/download/file02_2015-16_provenienze.csv
#
# n.b da specificare:
#
# Informazioni anagrafiche scuole delle province autonome di Aosta, Trento e Bolzano equiparate a scuole statali.
# Nel flusso di dati sono contenute le informazioni riguardanti l'anagrafe delle scuole province autonome di Aosta, Trento e Bolzano equiparate a scuole statali.
#
# Dati 2016/2017 (i più aggiornati, non stesso anno di edilizia ma poco importa)
#
# ** Anagrafica scuole - Anno 2017-2018** (link alla cartella data, come negli altri)
#    * [Informazioni anagrafiche scuole statali](http://dati.istruzione.it/opendata/opendata/catalogo/elements1/leaf/AS1718SCUANAGRAFESTAT20170731.csv)
#
#    * [Informazioni anagrafiche scuole paritarie](http://dati.istruzione.it/opendata/opendata/catalogo/elements1/AS1718SCUANAGRAFEPAR20170731.csv)
#
#    * [Informazioni anagrafiche scuole delle province autonome di Aosta, Trento e Bolzano equiparate a scuole statali](http://dati.istruzione.it/opendata/opendata/catalogo/elements1/AS1718SCUANAAUTSTAT20170731.csv)
#
#    * [Informazioni anagrafiche scuole paritarie delle province autonome di Aosta, Trento e Bolzano](http://dati.istruzione.it/opendata/opendata/catalogo/elements1/AS1718SCUANAAUTPAR20170731.csv)
#
#
# ** Studenti **
#
#    * [Studenti per anno di corso e fascia di eta'. Scuola statale](http://dati.istruzione.it/opendata/opendata/catalogo/elements1/leaf/ALUCORSOETASTA20170221.csv)
#
#    * [Studenti per anno di corso e fascia di eta'. Scuola paritaria](http://dati.istruzione.it/opendata/opendata/catalogo/elements1/leaf/ALUCORSOETAPAR20170221.csv)
#
#
# ** Edilizia scuola **
#
#    * [Elenco degli edifici scolastici statali attivi e loro locazione.](http://dati.istruzione.it/opendata/opendata/catalogo/elements1/EDIANAGRAFESTA20160831.csv)
#    * [Presenza vincoli degli edifici scolastici statali (idrogeologici, sismici...)](http://dati.istruzione.it/opendata/opendata/catalogo/elements1/EDIVINCOLISTA20160831.csv)
#    * [Uso di origine e data di costruzione e degli edifici scolastici statali.](http://dati.istruzione.it/opendata/opendata/catalogo/elements1/EDIETAORIGINESTA20160831.csv)
#    * [Superfici e volumi degli edifici scolastici statali (mq).](http://dati.istruzione.it/opendata/opendata/catalogo/elements1/EDICONSISTENZASTA20160831.csv)
#    * [Raggiungibilita' degli edifici scolastici statali (mezzi pubblici, scuolabus..)](http://dati.istruzione.it/opendata/opendata/catalogo/elements1/EDICOLLEGAMENTISTA20160831.csv)
#
#
#
#
# ### Registro degli Aiuti di Stato
# Registro Nazionale Aiuti che integra gli aiuti e degli incentivi alle imprese
# http://Registro%20nazionale%20degli%20aiuti

# %% [markdown]
# ## Data Pipeline

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import os
from pandas import DataFrame 
from IPython.display import display, HTML
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all" #setta l'esecuzione di più statement in unica cella

pd.set_option('display.max_colwidth', -1) 
pd.set_option('display.width', 5000) 
pd.set_option('display.max_columns', 100) 
# Set up formatting so larger numbers aren't displayed in scientific notation (h/t @thecapacity)
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %% [markdown]
# ### Open Cup - Metadati

# %%
#metadati_cup
metadati_cup = pd.read_excel("data/Metadati_OPENDATA.xlsx", sheetname="Elenco campi  definizioni")
metadati_cup
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-47a6c6fa6d14> in <module>()
#       1 #metadati_cup
# ----> 2 metadati_cup = pd.read_excel("data/Metadati_OPENDATA.xlsx", sheetname="Elenco campi  definizioni")
#       3 metadati_cup
#
# //anaconda/envs/py36/lib/python3.6/site-packages/pandas/io/excel.py in read_excel(io, sheetname, header, skiprows, skip_footer, index_col, names, parse_cols, parse_dates, date_parser, na_values, thousands, convert_float, has_index_names, converters, dtype, true_values, false_values, engine, squeeze, **kwds)
#     198
#     199     if not isinstance(io, ExcelFile):
# --> 200         io = ExcelFile(io, engine=engine)
#     201
#     202     return io._parse_excel(
#
# //anaconda/envs/py36/lib/python3.6/site-packages/pandas/io/excel.py in __init__(self, io, **kwds)
# ...

# %% [markdown]
# ### Open Cup - Dati

# %%
#Viene indicato che è stata usata ANSI - encoding='latin1', encoding='iso-8859-1' or encoding='cp1252'
cup = pd.read_csv("data/cup/CUP.csv", sep='|',encoding='iso-8859-1',  error_bad_lines=False, warn_bad_lines=True)
#! 87 lines skipped 

## Carico i Cup che provengono dall'aiuto --> Tralascio, non sembra essere rilevante
#aiuti_cup = pd.read_csv("data/CUP_aiuti.csv", sep=',')
#cup_aiuti = pd.merge(cup, aiuti_cup, on="CUP" )
# Out:
# b'Skipping line 1907: expected 73 fields, saw 118\n'
# b'Skipping line 38483: expected 73 fields, saw 138\n'
# b'Skipping line 57886: expected 73 fields, saw 118\nSkipping line 62887: expected 73 fields, saw 118\n'
# b'Skipping line 68501: expected 73 fields, saw 138\nSkipping line 71900: expected 73 fields, saw 138\n'
# b'Skipping line 78493: expected 73 fields, saw 138\n'
# b'Skipping line 87767: expected 73 fields, saw 138\n'
# b'Skipping line 94426: expected 73 fields, saw 138\nSkipping line 96031: expected 73 fields, saw 119\n'
# b'Skipping line 110129: expected 73 fields, saw 120\n'
# b'Skipping line 116684: expected 73 fields, saw 138\nSkipping line 121471: expected 73 fields, saw 118\n'
# b'Skipping line 140739: expected 73 fields, saw 137\nSkipping line 145387: expected 73 fields, saw 118\n'
# b'Skipping line 147635: expected 73 fields, saw 138\nSkipping line 148836: expected 73 fields, saw 118\n'
# b'Skipping line 156680: expected 73 fields, saw 118\n'
# ...

# %%
#elenco colonne per salvare
cup_column_keep = ['CUP',
 'DESCRIZIONE_SINTETICA_CUP',
 'ANNO_DECISIONE',
 'STATO_PROGETTO',
 'COSTO_PROGETTO',
 'FINANZIAMENTO_PROGETTO',
 'CODICE_STATO',
 'STATO',
 'CODICE_AREA_GEOGRAFICA',
 'AREA_GEOGRAFICA',
 'CODICE_REGIONE',
 'REGIONE',
 'CODICE_PROVINCIA',
 'SIGLA_PROVINCIA',
 'PROVINCIA',
 'CODICE_COMUNE',
 'COMUNE',
 'SOGGETTO_TITOLARE',
 'LOCALITA_SOG_TITOLARE',
 'COMUNE_SOGGETTO_TITOLARE',
 'SOTTOCATEGORIA_SOGGETTO',
 'CATEGORIA_SOGGETTO',
 'AREA_SOGGETTO',
 'CODICE_NATURA_INTERVENTO',
 'NATURA_INTERVENTO',
 'TIPOLOGIA_INTERVENTO',
 'CODICE_AREA_INTERVENTO',
 'AREA_INTERVENTO',
 'SETTORE_INTERVENTO',
 'SOTTOSETTORE_INTERVENTO',
 'CATEGORIA_INTERVENTO',
 'SOGGETTO_RICHIEDENTE',
 'TIPOLOGIA_CUP',
 'DESCRIZIONE_INTERVENTO',
 'STRUTTURA_INFRASTRUTTURA',
 'INDIRIZZO_INTERVENTO',
 'ANNO_DELIBERA',
 'FINANZA_PROGETTO',
 'STRUMENTO_PROGRAMMAZIONE',
 'COPERTURA_FINANZIARIA'
]

# %%
#casto gli importi
cup['COSTO_PROGETTO'] = cup['COSTO_PROGETTO'].astype(float)
cup['FINANZIAMENTO_PROGETTO'] = cup['FINANZIAMENTO_PROGETTO'].astype(float)
print (cup.shape)
cup = cup[cup_column_keep]
print (cup.shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-c2e193e639ba> in <module>()
#       1 #casto gli importi
# ----> 2 cup['COSTO_PROGETTO'] = cup['COSTO_PROGETTO'].astype(float)
#       3 cup['FINANZIAMENTO_PROGETTO'] = cup['FINANZIAMENTO_PROGETTO'].astype(float)
#       4 print (cup.shape)
#       5 cup = cup[cup_column_keep]
#
# //anaconda/envs/py36/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#      89                 else:
#      90                     kwargs[new_arg_name] = new_arg_value
# ---> 91             return func(*args, **kwargs)
#      92         return wrapper
#      93     return _deprecate_kwarg
#
# //anaconda/envs/py36/lib/python3.6/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    3297         # else, only a single dtype is given
# ...

# %%
cup.head(10)
# Out:
#                CUP                                                                                                                                                                                                                                                                                                                                                                                                                                      DESCRIZIONE_SINTETICA_CUP ANNO_DECISIONE STATO_PROGETTO COSTO_PROGETTO FINANZIAMENTO_PROGETTO CODICE_STATO   STATO CODICE_AREA_GEOGRAFICA AREA_GEOGRAFICA  CODICE_REGIONE         REGIONE CODICE_PROVINCIA SIGLA_PROVINCIA           PROVINCIA  CODICE_COMUNE                   COMUNE                                                 SOGGETTO_TITOLARE     LOCALITA_SOG_TITOLARE COMUNE_SOGGETTO_TITOLARE    SOTTOCATEGORIA_SOGGETTO                                                                 CATEGORIA_SOGGETTO           AREA_SOGGETTO  CODICE_NATURA_INTERVENTO   
# ...

# %% [markdown]
# ### ItaliaSicura - Dati
#
# Carico tutti gli interventi fatti dallo Stato sull'edilizia scolastica (a partire dal 2004)
# Verificare la data minima

# %%
#carico tutti i file provenienti da ItaliaSicura in un unico dataset
#cambia il nome del file ma la struttura dati e header ha lo stesso formato per tutti.
# attenzione: keep leading zeros
#https://stackoverflow.com/questions/13250046/pandas-csv-import-keep-leading-zeros-in-a-column
fileDir = os.path.dirname(os.path.realpath('__file__'))
output_folder = os.path.join(fileDir, 'data/cantieriscuole')
listing = os.listdir(output_folder)   
#loop in csv files from folder
cantieri = DataFrame()
list_ = []

for infile in listing: 
    #filename = os.path.join(fileDir, infile)
    filename = os.path.join(output_folder, infile)
    filehandle = open(filename)
    print (filehandle) 
    data = pd.read_csv(filehandle, sep="|", index_col=None, header=0, encoding='UTF-8',converters={'CODICE_EDIFICIO': lambda x: str(x)})
    list_.append(data)
cantieri = pd.concat(list_)
# Out:
# <_io.TextIOWrapper name='/Users/mariaclaudiabodino/DEVELOPMENT/DAF/ScuoleSicure/data/cantieriscuole/open_data_interventi_finanziamenti_edilizia_scolastica-22.csv' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/mariaclaudiabodino/DEVELOPMENT/DAF/ScuoleSicure/data/cantieriscuole/open_data_interventi_finanziamenti_edilizia_scolastica-20.csv' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/mariaclaudiabodino/DEVELOPMENT/DAF/ScuoleSicure/data/cantieriscuole/open_data_interventi_finanziamenti_edilizia_scolastica-21.csv' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/mariaclaudiabodino/DEVELOPMENT/DAF/ScuoleSicure/data/cantieriscuole/open_data_interventi_finanziamenti_edilizia_scolastica-19.csv' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/mariaclaudiabodino/DEVELOPMENT/DAF/ScuoleSicure/data/cantieriscuole/open_data_interventi_finanziamenti_edilizia_scolastica-18.csv' mode='r' encoding='UTF-8'>
# ...

# %%
#rinomino il campo in CUP come su Open Cup
cantieri = cantieri.rename(columns={'Codice progetto':'CUP', "CODICE_EDIFICIO":'CODICEEDIFICIO'})

# %%
cantieri['Importo totale opera'] = cantieri['Importo totale opera'].str.replace(",",".").astype(float)
cantieri['Finanziamento/ Provvedimento'] = cantieri['Finanziamento/ Provvedimento'].str.replace(",",".").astype(float)
cantieri.to_csv("cantieri.csv", sep='|',index=False, header=True,  encoding='utf-8')

# %%
#salva solo i cantieri di Cuneo
cantieri_cn=cantieri.loc[cantieri["PROVINCIA"]=="Cuneo"]
cantieri_cn.shape
cantieri_cn.to_csv("cantieri_cn.csv", sep='|',index=False, header=True,  encoding='utf-8')

#record non riconducibili al codice edificio
print("Codice EDIFICIO null su Cuneo: ",len(cantieri_cn[cantieri_cn["CODICEEDIFICIO"].isnull()]))
print("Codice progetto/CUP null Cuneo: ",len(cantieri_cn[cantieri_cn["CUP"].isnull()]))
# Out:
# (234, 25)
# Codice EDIFICIO null su Cuneo:  0
# Codice progetto/CUP null Cuneo:  13

# %% [markdown]
# ### MIUR - Dati - Alunni per edifici scolastici
#
# NB: i nomi colonne hanno uno space iniziale - esegui strip()

# %%
# Creo il dataframe SCUOLE con le info basi delle scuole
#Carico file di anagrafica base delle scuole
fileDir = os.path.dirname(os.path.realpath('__file__'))
output_folder = os.path.join(fileDir, 'data/MIUR/anagrafica')
listing = os.listdir(output_folder)   
#loop in csv files from folder
scuole = DataFrame()
list_ = []

for infile in listing: 
    #filename = os.path.join(fileDir, infile)
    filename = os.path.join(output_folder, infile)
    filehandle = open(filename)
    print (filehandle) 
    data = pd.read_csv(filehandle, sep=",", index_col=None, header=0)
    list_.append(data)
scuole = pd.concat(list_)

scuole = scuole.rename(columns=lambda x: x.strip())
# Out:
# <_io.TextIOWrapper name='/Users/mariaclaudiabodino/DEVELOPMENT/DAF/ScuoleSicure/data/MIUR/anagrafica/AS1718SCUANAAUTSTAT20170731.csv' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/mariaclaudiabodino/DEVELOPMENT/DAF/ScuoleSicure/data/MIUR/anagrafica/AS1718SCUANAGRAFESTAT20170731.csv' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/mariaclaudiabodino/DEVELOPMENT/DAF/ScuoleSicure/data/MIUR/anagrafica/AS1718SCUANAGRAFEPAR20170731.csv' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/mariaclaudiabodino/DEVELOPMENT/DAF/ScuoleSicure/data/MIUR/anagrafica/AS1718SCUANAAUTPAR20170731.csv' mode='r' encoding='UTF-8'>

# %%
scuole.shape
#scuole_columns = list(scuole)
scuole_columns_to_keep =[
 'AREAGEOGRAFICA',
 'CODICEISTITUTORIFERIMENTO',
 'CODICESCUOLA',
 'DENOMINAZIONEISTITUTORIFERIMENTO',
 'DENOMINAZIONESCUOLA',
 'DESCRIZIONECOMUNE',
 'DESCRIZIONETIPOLOGIAGRADOISTRUZIONESCUOLA',
 'INDIRIZZOSCUOLA',
 'PROVINCIA',
 'REGIONE']
#elimino le colonne non necessarie
scuole = scuole[scuole_columns_to_keep]
scuole.shape
# Out:
# (65503, 19)
# (65503, 10)

# %%
scuole_cn=scuole.loc[scuole["PROVINCIA"]=="CUNEO"]
print ("Tot codici scuola univoca per provincia CUNEO: ",scuole_cn.CODICESCUOLA.nunique())
scuole_cn.groupby(["DESCRIZIONETIPOLOGIAGRADOISTRUZIONESCUOLA"]).count()
# Out:
# Tot codici scuola univoca per provincia CUNEO:  786
#                                                    AREAGEOGRAFICA  CODICEISTITUTORIFERIMENTO  CODICESCUOLA  DENOMINAZIONEISTITUTORIFERIMENTO  DENOMINAZIONESCUOLA  DESCRIZIONECOMUNE  INDIRIZZOSCUOLA  PROVINCIA  REGIONE
# DESCRIZIONETIPOLOGIAGRADOISTRUZIONESCUOLA
# CENTRO TERRITORIALE                                4               4                          4             4                                 4                    4                  4                4          4
# IST  PROF  PER I SERVIZI COMMERCIALI               1               1                          1             1                                 1                    1                  1                1          1
# IST PROF INDUSTRIA E ARTIGIANATO                   8               8                          8             8                                 8                    8                  8                8          8
# ...

# %%
#ISTITUTI STATALI - raggruppo per CODICESCUOLA
alunni_statali = pd.read_csv("data/MIUR/alunni/ALUCORSOETASTA20170221.csv", sep=',')

#clean columns name
alunni_statali = alunni_statali.rename(columns=lambda x: x.strip())
print ("Unique edifici statali: ", alunni_statali["CODICESCUOLA"].nunique())
alunni_statali = alunni_statali[["CODICESCUOLA", "ALUNNI"]]
alunni_statali= alunni_statali.groupby(['CODICESCUOLA']).sum()
alunni_statali["Tipo"]='S'
alunni_statali = alunni_statali.reset_index()
alunni_statali.head(5)
# Out:
# Unique edifici statali:  28272
#   CODICESCUOLA  ALUNNI Tipo
# 0  AGEE01102E   263     S
# 1  AGEE01104L   364     S
# 2  AGEE02405Q   106     S
# 3  AGEE02406R   198     S
# 4  AGEE02407T   189     S

# %%
#ISTITUTI PARITARI - raggruppo per CODICESCUOLA
alunni_paritari = pd.read_csv("data/MIUR/alunni/ALUCORSOETAPAR20170221.csv", sep=',')
#clean columns name
alunni_paritari = alunni_paritari.rename(columns=lambda x: x.strip())
alunni_paritari = alunni_paritari[["CODICESCUOLA", "ALUNNI"]]
print ("Unique edifici paritari: ", alunni_paritari["CODICESCUOLA"].nunique())
alunni_paritari= alunni_paritari.groupby(['CODICESCUOLA']).sum()
alunni_paritari["Tipo"]='P'
alunni_paritari = alunni_paritari.reset_index()
# Out:
# Unique edifici paritari:  3587

# %%
#uniamo i due dataset su CODICESCUOLA e numero alunni in uno unico
alunni= pd.concat([alunni_statali, alunni_paritari])
alunni.head()
# Out:
#   CODICESCUOLA  ALUNNI Tipo
# 0  AGEE01102E   263     S
# 1  AGEE01104L   364     S
# 2  AGEE02405Q   106     S
# 3  AGEE02406R   198     S
# 4  AGEE02407T   189     S

# %%
print(alunni.loc[alunni["CODICESCUOLA"]=="CNTF010005"])
# Out:
#      CODICESCUOLA  ALUNNI Tipo
# 6362  CNTF010005   878     S

# %%
# join scuole e alunni - per ogni scuola il numero totale di alunni e info anagrafica della scuola
print ("Iniziale: ", len(scuole), "  ", len(alunni))
scuole_alunni = pd.merge(scuole, alunni, how="left",on='CODICESCUOLA')
print ("Finale: ",len(scuole_alunni))
scuole_alunni.to_csv("scuoleAlunni.csv", sep='|',index=False, header=True,  encoding='utf-8')
# Out:
# Iniziale:  65503    31859
# Finale:  65503

# %%
# join scuole e alunni
print ("Iniziale: ", len(scuole_cn), "  ", len(alunni))
scuole_alunni_cn = pd.merge(scuole_cn, alunni, how="left",on='CODICESCUOLA')
print ("Finale: ",len(scuole_alunni_cn))
scuole_alunni_cn.to_csv("scuoleAlunni_cn.csv", sep='|',index=False, header=True,  encoding='utf-8')
# Out:
# Iniziale:  786    31859
# Finale:  786

# %%
scuole_alunni_cn.to_csv("scuoleAlunni.csv", sep='|',index=False, header=True,  encoding='utf-8')

# %% [markdown]
# ### Edilizia scuola

# %%
#Localizzazione  degli edifici scolastici statali attivi - una scuola può avere più edifici
#NB il codiceedificio va forzato e letto con uno space 
edifici = pd.read_csv("data/MIUR/edilizia/EDIANAGRAFESTA20160831.csv", sep=',',converters={' CODICEEDIFICIO': lambda x: str(x)})
edifici = edifici.rename(columns=lambda x: x.strip())
edifici.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50804 entries, 0 to 50803
# Data columns (total 11 columns):
# ANNOSCOLASTICO            50804 non-null int64
# CODICESCUOLA              50804 non-null object
# CODICEEDIFICIO            50804 non-null object
# CODICECOMUNE              50804 non-null object
# DESCRIZIONECOMUNE         50804 non-null object
# SIGLAPROVINCIA            49503 non-null object
# TIPOLOGIAINDIRIZZO        50804 non-null object
# DENOMINAZIONEINDIRIZZO    50804 non-null object
# NUMEROCIVICO              50804 non-null object
# CAP                       50804 non-null object
# STATOEDIFICIO             50804 non-null object
# dtypes: int64(1), object(10)
# memory usage: 4.3+ MB

# %%
#mantengo solo le info che mi permettono di fare join
#edifici_columns = list(edifici)
edifici_columns_to_keep = [
 'CODICESCUOLA',
 'CODICEEDIFICIO',
 'SIGLAPROVINCIA',  
 'STATOEDIFICIO']
edifici = edifici[edifici_columns_to_keep]
edifici.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50804 entries, 0 to 50803
# Data columns (total 4 columns):
# CODICESCUOLA      50804 non-null object
# CODICEEDIFICIO    50804 non-null object
# SIGLAPROVINCIA    49503 non-null object
# STATOEDIFICIO     50804 non-null object
# dtypes: object(4)
# memory usage: 1.6+ MB

# %%
#isolo gli edifici di CUNEO
edifici_cn = edifici.loc[edifici["SIGLAPROVINCIA"]=="CN"]

# %%
edifici_cn.shape
# Out:
# (698, 4)

# %%
#VINCOLI degli edifici scolastici statali 
edifici_v = pd.read_csv("data/MIUR/edilizia/EDIVINCOLISTA20160831.csv", sep=',',converters={' CODICEEDIFICIO': lambda x: str(x)})
edifici_v = edifici_v.rename(columns=lambda x: x.strip())
edifici_v.info()
edifici_v["VINCOLIZONASISMICA"].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50804 entries, 0 to 50803
# Data columns (total 8 columns):
# ANNOSCOLASTICO              50804 non-null int64
# CODICESCUOLA                50804 non-null object
# CODICEEDIFICIO              50804 non-null object
# VINCOLIIDROGEOLOGICI        50804 non-null object
# VINCOLIPAESAGGIO            50804 non-null object
# EDIFICIOVETUSTO             50804 non-null object
# VINCOLIZONASISMICA          50804 non-null object
# PROGETTAZIONEANTISISMICA    50804 non-null object
# dtypes: int64(1), object(7)
# memory usage: 3.1+ MB
# Rischio sismicità medio/alta (S=9)    18622
# Rischio bassa sismicità (S=6)         14970
# Non classificato a rischio            13018
# Rischio elevata sismicità (S=12)      3578
# Non Comunicato                        616
# Name: VINCOLIZONASISMICA, dtype: int64

# %%
#ETA, numero piani degli edifici scolastici statali 
edifici_o = pd.read_csv("data/MIUR/edilizia/EDIETAORIGINESTA20160831.csv", sep=',',converters={' CODICEEDIFICIO': lambda x: str(x)})
edifici_o = edifici_o.rename(columns=lambda x: x.strip())
edifici_o.info()
edifici_o.head(3)
edifici_o.CODICEEDIFICIO.nunique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50804 entries, 0 to 50803
# Data columns (total 10 columns):
# ANNOSCOLASTICO          50804 non-null int64
# CODICESCUOLA            50804 non-null object
# CODICEEDIFICIO          50804 non-null object
# USOSCOLASTICO           50804 non-null object
# ALTRIUSI                50804 non-null object
# ANNOCOSTRUZIONE         50804 non-null object
# FASCIAETACOSTRUZIONE    50804 non-null object
# ANNOADATTAMENTO         50804 non-null object
# FASCIAETAADATTAMENTO    50804 non-null object
# NUMEROPIANI             50804 non-null int64
# dtypes: int64(2), object(8)
# memory usage: 3.9+ MB
#    ANNOSCOLASTICO CODICESCUOLA CODICEEDIFICIO USOSCOLASTICO ALTRIUSI ANNOCOSTRUZIONE   FASCIAETACOSTRUZIONE ANNOADATTAMENTO  FASCIAETAADATTAMENTO  NUMEROPIANI
# 0  201516          AGAA01103A   0840111102     SI            NO       -               tra il 1961 e il 1975  -               Informazione assente  1
# ...

# %%
#Collegamenti degli edifici scolastici statali: mensa, spazi didattici,... 
edifici_coll = pd.read_csv("data/MIUR/edilizia/EDICOLLEGAMENTISTA20160831.csv", sep=',',converters={' CODICEEDIFICIO': lambda x: str(x)})
edifici_coll = edifici_coll.rename(columns=lambda x: x.strip())
edifici_coll.info()
edifici_coll.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50804 entries, 0 to 50803
# Data columns (total 10 columns):
# ANNOSCOLASTICO                  50804 non-null int64
# CODICESCUOLA                    50804 non-null object
# CODICEEDIFICIO                  50804 non-null object
# SCUOLABUS                       50804 non-null object
# TRASPORTIPUBBLICIURBANI         50804 non-null object
# TRASPORTIPUBBLICIINTERURBANI    50804 non-null object
# TRASPORTIFERROVIARI             50804 non-null object
# MEZZIPRIVATI                    50804 non-null object
# TRASPORTODISABILI               50804 non-null object
# ALTRO                           50804 non-null object
# dtypes: int64(1), object(9)
# memory usage: 3.9+ MB
#    ANNOSCOLASTICO CODICESCUOLA CODICEEDIFICIO SCUOLABUS TRASPORTIPUBBLICIURBANI TRASPORTIPUBBLICIINTERURBANI TRASPORTIFERROVIARI MEZZIPRIVATI TRASPORTODISABILI           ALTRO
# ...

# %%
#Ambienti degli edifici scolastici statali: mensa, spazi didattici,... 
edifici_funz = pd.read_csv("data/MIUR/edilizia/EDIAMBFUNZSTA20160831.csv", sep=',',converters={' CODICEEDIFICIO': lambda x: str(x)})
edifici_funz = edifici_funz.rename(columns=lambda x: x.strip())
edifici_funz.info()
edifici_funz.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50804 entries, 0 to 50803
# Data columns (total 8 columns):
# ANNOSCOLASTICO         50804 non-null int64
# CODICESCUOLA           50804 non-null object
# CODICEEDIFICIO         50804 non-null object
# SPAZIDIDATTICI         50804 non-null object
# AULAMAGNA              50804 non-null object
# MENSA                  50804 non-null object
# PALESTRAPISCINA        50804 non-null object
# SPAZIAMMINISTRATIVI    50804 non-null object
# dtypes: int64(1), object(7)
# memory usage: 3.1+ MB
#    ANNOSCOLASTICO CODICESCUOLA CODICEEDIFICIO SPAZIDIDATTICI   AULAMAGNA       MENSA PALESTRAPISCINA SPAZIAMMINISTRATIVI
# 0  201516          AGAA01103A   0840111102     Esiste         Non Esiste  Non Esiste  Non Esiste      Non Esiste
# 1  201516          AGAA01109L   0840111103     Esiste         Non Esiste  Non Esiste  Non Esiste      Non Esiste
# ...

# %%
edifici_funz.MENSA.value_counts()
# Out:
# Non Esiste        35146
# Esiste            15117
# Non Comunicato    541
# Name: MENSA, dtype: int64

# %%
edifici_funz.SPAZIDIDATTICI.value_counts()
# Out:
# Esiste        43603
# Non Esiste    7201
# Name: SPAZIDIDATTICI, dtype: int64

# %%
edifici_funz.PALESTRAPISCINA.value_counts()
# Out:
# Non Esiste        31552
# Esiste            19188
# Non Comunicato    64
# Name: PALESTRAPISCINA, dtype: int64

# %%
#Dimensioni/Superficie degli edifici scolastici statali 
edifici_d = pd.read_csv("data/MIUR/edilizia/EDICONSISTENZASTA20160831.csv", sep=',',converters={' CODICEEDIFICIO': lambda x: str(x)})
edifici_d = edifici_d.rename(columns=lambda x: x.strip())
edifici_d.info()
edifici_d.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50804 entries, 0 to 50803
# Data columns (total 6 columns):
# ANNOSCOLASTICO         50804 non-null int64
# CODICESCUOLA           50804 non-null object
# CODICEEDIFICIO         50804 non-null object
# SPERFICIEAREATOTALE    50804 non-null object
# SPERFICIEAREALIBERA    50804 non-null object
# VOLUME                 50804 non-null object
# dtypes: int64(1), object(5)
# memory usage: 2.3+ MB
#    ANNOSCOLASTICO CODICESCUOLA CODICEEDIFICIO SPERFICIEAREATOTALE SPERFICIEAREALIBERA    VOLUME
# 0  201516          AGAA01103A   0840111102     3.000,00            2.100,00            3.600,00
# 1  201516          AGAA01109L   0840111103     18.000,00           6.000,00            9.000,00
# 2  201516          AGAA02406G   0840274812     1.400,00            455,00              4.930,00

# %%
# 1 _CUNEO join BASE: Info base SCUOLA + join edifici su CODICESCUOLA
print ("scuole unique: ",scuole_cn.CODICESCUOLA.nunique())
print ("Iniziale: ",len(scuole_cn), "  ", len(edifici))
edifici_1_cn = pd.merge(scuole_cn, edifici, how='left',on='CODICESCUOLA', suffixes=('','_drop'))
edifici_1_cn = edifici_1_cn.drop([col for col in edifici_1_cn.columns if '_drop' in col],axis=1)
print ("Finale: ",len(edifici_1_cn), "-", edifici_1_cn.CODICESCUOLA.nunique() )
edifici_1_cn.to_csv("edifici_1_cn.csv", sep='|',index=False, header=True,  encoding='utf-8')
# Out:
# scuole unique:  786
# Iniziale:  786    50804
# Finale:  899 - 786

# %%
# 1 _ ITALIA join BASE: Info base SCUOLA + join edifici su CODICESCUOLA
print ("scuole unique: ",scuole.CODICESCUOLA.nunique())
print ("Iniziale: ",len(scuole), "  ", len(edifici))
edifici_1 = pd.merge(scuole, edifici, how='left',on='CODICESCUOLA', suffixes=('','_drop'))
edifici_1 = edifici_1.drop([col for col in edifici_1.columns if '_drop' in col],axis=1)
print ("Finale: ",len(edifici_1), "-", edifici_1.CODICESCUOLA.nunique() )
edifici_1.to_csv("edifici_1.csv", sep='|',index=False, header=True,  encoding='utf-8')
# Out:
# scuole unique:  65503
# Iniziale:  65503    50804
# Finale:  74225 - 65503

# %%
# 2 CUNEO join, il precedente più i vincoli  - edifici_1 + edifici_v
print ("Iniziale: ", len(edifici_1_cn), "  ", len(edifici_v))
edifici_2_cn = pd.merge(edifici_1_cn, edifici_v, how='left',on=['CODICESCUOLA','CODICEEDIFICIO'], suffixes=('','_drop'))
edifici_2_cn = edifici_2_cn.drop([col for col in edifici_2_cn.columns if '_drop' in col],axis=1)
print ("Finale: ",len(edifici_2_cn),"-",edifici_2_cn.CODICESCUOLA.nunique())
edifici_2_cn.to_csv("edifici_2_cn.csv", sep='|',index=False, header=True,  encoding='utf-8')
# Out:
# Iniziale:  899    50804
# Finale:  899 - 786

# %%
# 2 ITALIA join, il precedente più i vincoli  - edifici_1 + edifici_v
print ("Iniziale: ", len(edifici_1), "  ", len(edifici_v))
edifici_2 = pd.merge(edifici_1, edifici_v, how='left',on=['CODICESCUOLA','CODICEEDIFICIO'], suffixes=('','_drop'))
edifici_2 = edifici_2.drop([col for col in edifici_2.columns if '_drop' in col],axis=1)
print ("Finale: ",len(edifici_2),"-",edifici_2.CODICESCUOLA.nunique())
edifici_2_cn.to_csv("edifici_2.csv", sep='|',index=False, header=True,  encoding='utf-8')
# Out:
# Iniziale:  74225    50804
# Finale:  74225 - 65503

# %%
# 3 CUNEO join, il precedente più eta - edifici_2 + edifici_o
print ("Iniziale: ", len(edifici_2_cn), "  ", len(edifici_o))
edifici_3_cn = pd.merge(edifici_2_cn, edifici_o, how='left',on=['CODICESCUOLA','CODICEEDIFICIO'],suffixes=('','_drop'))
edifici_3_cn = edifici_3_cn.drop([col for col in edifici_3_cn.columns if '_drop' in col],axis=1)
print ("Finale: ",len(edifici_3_cn),"-",edifici_3_cn.CODICESCUOLA.nunique())
edifici_3_cn.to_csv("edifici_3_cn.csv", sep='|',index=False, header=True,  encoding='utf-8')
# Out:
# Iniziale:  899    50804
# Finale:  899 - 786

# %%
# 3 ITALIA join, il precedente più eta - edifici_2 + edifici_o
print ("Iniziale: ", len(edifici_2), "  ", len(edifici_o))
edifici_3 = pd.merge(edifici_2, edifici_o, how='left',on=['CODICESCUOLA','CODICEEDIFICIO'],suffixes=('','_drop'))
edifici_3 = edifici_3.drop([col for col in edifici_3.columns if '_drop' in col],axis=1)
print ("Finale: ",len(edifici_3),"-",edifici_3.CODICESCUOLA.nunique())
edifici_3.to_csv("edifici_3.csv", sep='|',index=False, header=True,  encoding='utf-8')
# Out:
# Iniziale:  74225    50804
# Finale:  74225 - 65503

# %%
# 4 CUNEO join, il precedente più eta - edifici_3 + edifici_funz
print ("Iniziale: ", len(edifici_3_cn), "  ", len(edifici_d))
edifici_4_cn = pd.merge(edifici_3_cn, edifici_d, how='left',on=['CODICESCUOLA','CODICEEDIFICIO'],suffixes=('','_drop'))
edifici_4_cn = edifici_4_cn.drop([col for col in edifici_4_cn.columns if '_drop' in col],axis=1)
print ("Finale: ",len(edifici_4_cn),"-",edifici_4_cn.CODICESCUOLA.nunique())
edifici_4_cn.to_csv("edifici_4_cn.csv", sep='|',index=False, header=True,  encoding='utf-8')
# Out:
# Iniziale:  899    50804
# Finale:  899 - 786

# %%
# 4 ITALIA join, il precedente più eta - edifici_3 + edifici_funz
print ("Iniziale: ", len(edifici_3), "  ", len(edifici_d))
edifici_4 = pd.merge(edifici_3, edifici_d, how='left',on=['CODICESCUOLA','CODICEEDIFICIO'],suffixes=('','_drop'))
edifici_4 = edifici_4.drop([col for col in edifici_4.columns if '_drop' in col],axis=1)
print ("Finale: ",len(edifici_4),"-",edifici_4.CODICESCUOLA.nunique())
edifici_4.to_csv("edifici_4.csv", sep='|',index=False, header=True,  encoding='utf-8')
# Out:
# Iniziale:  74225    50804
# Finale:  74225 - 65503

# %%
# 5 CUNEO join, il precedente più eta - edifici_3 + edifici_funz
print ("Iniziale: ", len(edifici_4_cn), "  ", len(edifici_funz))
edifici_5_cn = pd.merge(edifici_4_cn, edifici_funz, how='left',on=['CODICESCUOLA','CODICEEDIFICIO'],suffixes=('','_drop'))
print ("Finale: ",len(edifici_5_cn),"-",edifici_5_cn.CODICESCUOLA.nunique())
edifici_5_cn = edifici_5_cn.drop([col for col in edifici_5_cn.columns if '_drop' in col],axis=1)
edifici_5_cn.to_csv("edifici_5_cn.csv", sep='|',index=False, header=True,  encoding='utf-8')
# Out:
# Iniziale:  899    50804
# Finale:  899 - 786

# %%
# 5 ITALIA join, il precedente più eta - edifici_3 + edifici_funz
print ("Iniziale: ", len(edifici_4), "  ", len(edifici_funz))
edifici_5 = pd.merge(edifici_4, edifici_funz, how='left',on=['CODICESCUOLA','CODICEEDIFICIO'],suffixes=('','_drop'))
print ("Finale: ",len(edifici_5),"-",edifici_5.CODICESCUOLA.nunique())
edifici_5 = edifici_5.drop([col for col in edifici_5.columns if '_drop' in col],axis=1)
edifici_5.to_csv("edifici_5.csv", sep='|',index=False, header=True,  encoding='utf-8')
# Out:
# Iniziale:  74225    50804
# Finale:  74225 - 65503

# %%
# 6 CUNEO join, il precedente più  edifici_coll
print ("Iniziale: ", len(edifici_5_cn), "  ", len(edifici_coll))
edifici_6_cn = pd.merge(edifici_5_cn, edifici_coll, how='left',on=['CODICESCUOLA','CODICEEDIFICIO'],suffixes=('','_drop'))
print ("Finale: ",len(edifici_6_cn),"-",edifici_5_cn.CODICESCUOLA.nunique())
edifici_6_cn = edifici_6_cn.drop([col for col in edifici_5_cn.columns if '_drop' in col],axis=1)
edifici_6_cn.to_csv("edifici_6_cn.csv", sep='|',index=False, header=True,  encoding='utf-8')
# Out:
# Iniziale:  899    50804
# Finale:  899 - 786

# %%
# 6 ITALIA join, il precedente più  edifici_coll
print ("Iniziale: ", len(edifici_5), "  ", len(edifici_coll))
edifici_6 = pd.merge(edifici_5, edifici_coll, how='left',on=['CODICESCUOLA','CODICEEDIFICIO'],suffixes=('','_drop'))
print ("Finale: ",len(edifici_6),"-",edifici_5.CODICESCUOLA.nunique())
edifici_6 = edifici_6.drop([col for col in edifici_5.columns if '_drop' in col],axis=1)
edifici_6.to_csv("edifici_6.csv", sep='|',index=False, header=True,  encoding='utf-8')
# Out:
# Iniziale:  74225    50804
# Finale:  74225 - 65503

# %%
# CUNEO JOIN su EDIFICI E CANTIERI (fondi destinati ai cantieri) - come campo hai solo il codice edificio
print ("Iniziale: ",len(edifici_6_cn), "  ", len(cantieri_cn))
edifici_6_cn_cantieri = pd.merge(edifici_6_cn, cantieri_cn,how='left',on='CODICEEDIFICIO',suffixes=('','_drop'))
#edifici_5_cn_cantieri = edifici_5_cn_cantieri.drop([col for col in edifici_5_cn_cantieri.columns if '_drop' in col],axis=1)
print ("Finale: ",len(edifici_6_cn_cantieri),"-",edifici_6_cn_cantieri.CODICESCUOLA.nunique())
edifici_6_cn_cantieri = edifici_6_cn_cantieri.drop([col for col in edifici_6_cn_cantieri.columns if '_drop' in col],axis=1)
# Out:
# Iniziale:  899    234
# Finale:  950 - 786

# %%
# ITALIA JOIN su EDIFICI E CANTIERI (fondi destinati ai cantieri) - come campo hai solo il codice edificio
print ("Iniziale: ",len(edifici_6), "  ", len(cantieri))
edifici_6_cantieri = pd.merge(edifici_6, cantieri,how='left',on='CODICEEDIFICIO',suffixes=('','_drop'))
#edifici_5_cn_cantieri = edifici_5_cn_cantieri.drop([col for col in edifici_5_cn_cantieri.columns if '_drop' in col],axis=1)
print ("Finale: ",len(edifici_6_cantieri),"-",edifici_6_cantieri.CODICESCUOLA.nunique())
edifici_6_cantieri = edifici_6_cantieri.drop([col for col in edifici_6_cantieri.columns if '_drop' in col],axis=1)
# Out:
# Iniziale:  74225    12604
# Finale:  77559 - 65503

# %%
edifici_6_cn_cantieri_column_to_keep = [
 'AREAGEOGRAFICA',
 'CODICEISTITUTORIFERIMENTO',
 'CODICESCUOLA',
 'DENOMINAZIONESCUOLA',
 'DESCRIZIONECOMUNE',
 'DESCRIZIONETIPOLOGIAGRADOISTRUZIONESCUOLA',
 'INDIRIZZOSCUOLA',
 'PROVINCIA',
 'REGIONE',
 'CODICEEDIFICIO',
 'SIGLAPROVINCIA',
 'STATOEDIFICIO',
 'VINCOLIIDROGEOLOGICI',
 'VINCOLIPAESAGGIO',
 'EDIFICIOVETUSTO',
 'VINCOLIZONASISMICA',
 'PROGETTAZIONEANTISISMICA',
 'USOSCOLASTICO',
 'ALTRIUSI',
 'ANNOCOSTRUZIONE',
 'FASCIAETACOSTRUZIONE',
 'ANNOADATTAMENTO',
 'FASCIAETAADATTAMENTO',
 'NUMEROPIANI',
 'SPERFICIEAREATOTALE',
 'SPERFICIEAREALIBERA',
 'VOLUME',
 'SPAZIDIDATTICI',
 'AULAMAGNA',
 'MENSA',
 'PALESTRAPISCINA',
 'SPAZIAMMINISTRATIVI',
 'SCUOLABUS',
 'TRASPORTIPUBBLICIURBANI',
 'TRASPORTIPUBBLICIINTERURBANI',
 'TRASPORTIFERROVIARI',
 'MEZZIPRIVATI',
 'TRASPORTODISABILI',
 'Linea_finanziamento',
 'COMUNE',
 'FONTE',
 'Data_aggiornamento_lavori',
 'Data_inizio',
 'Data_fine',
 'ENTE_RICHIEDENTE',
 'TIPOLOGIA_ENTE_RICHIEDENTE',
 'COD_PRINC',
 'OGGETTO_INTERVENTO',
 'INFO_AGGIUNTIVE',
 'LATITUDINE',
 'LONGITUDINE',
 'TIPO_INTERVENTO',
 'STATO LAVORI',
 'CUP',
 'Importo totale opera',
 'Finanziamento/ Provvedimento']
edifici_6_cn_cantieri= edifici_6_cn_cantieri [edifici_6_cn_cantieri_column_to_keep]
edifici_6_cantieri= edifici_6_cantieri [edifici_6_cn_cantieri_column_to_keep]
edifici_6_cn_cantieri.shape
edifici_6_cantieri.shape

edifici_6_cantieri.to_csv("edifici_6_cantieri.csv", sep='|',index=False, header=True,  encoding='utf-8')
edifici_6_cn_cantieri.to_csv("edifici_6_cn_cantieri.csv", sep='|',index=False, header=True,  encoding='utf-8')
# Out:
# (950, 56)
# (77559, 56)

# %%
edifici_6_cn_cantieri.head(5)
# Out:
#   AREAGEOGRAFICA CODICEISTITUTORIFERIMENTO CODICESCUOLA             DENOMINAZIONESCUOLA DESCRIZIONECOMUNE DESCRIZIONETIPOLOGIAGRADOISTRUZIONESCUOLA         INDIRIZZOSCUOLA PROVINCIA   REGIONE CODICEEDIFICIO SIGLAPROVINCIA STATOEDIFICIO VINCOLIIDROGEOLOGICI VINCOLIPAESAGGIO EDIFICIOVETUSTO VINCOLIZONASISMICA PROGETTAZIONEANTISISMICA USOSCOLASTICO ALTRIUSI ANNOCOSTRUZIONE FASCIAETACOSTRUZIONE ANNOADATTAMENTO FASCIAETAADATTAMENTO  NUMEROPIANI SPERFICIEAREATOTALE SPERFICIEAREALIBERA VOLUME SPAZIDIDATTICI AULAMAGNA MENSA PALESTRAPISCINA SPAZIAMMINISTRATIVI SCUOLABUS TRASPORTIPUBBLICIURBANI TRASPORTIPUBBLICIINTERURBANI TRASPORTIFERROVIARI MEZZIPRIVATI TRASPORTODISABILI Linea_finanziamento COMUNE FONTE Data_aggiornamento_lavori Data_inizio Data_fine ENTE_RICHIEDENTE TIPOLOGIA_ENTE_RICHIEDENTE COD_PRINC OGGETTO_INTERVENTO INFO_AGGIUNTIVE  LATITUDINE  LONGITUDINE TIPO_INTERVENTO STATO LAVORI  CUP  Importo totale opera  Finanziamento/ Provvedimento
# ...

# %%
#edifici_5_cn_cantieri.loc[edifici_5_cn_cantieri['CODICESCUOLA']=='CNAA84502A']
edifici_6_cn_cantieri.loc[edifici_6_cn_cantieri['CODICEEDIFICIO']=='0040780011']
# Out:
#     AREAGEOGRAFICA CODICEISTITUTORIFERIMENTO CODICESCUOLA      DENOMINAZIONESCUOLA DESCRIZIONECOMUNE DESCRIZIONETIPOLOGIAGRADOISTRUZIONESCUOLA             INDIRIZZOSCUOLA PROVINCIA   REGIONE CODICEEDIFICIO SIGLAPROVINCIA STATOEDIFICIO VINCOLIIDROGEOLOGICI VINCOLIPAESAGGIO EDIFICIOVETUSTO             VINCOLIZONASISMICA PROGETTAZIONEANTISISMICA USOSCOLASTICO ALTRIUSI ANNOCOSTRUZIONE  FASCIAETACOSTRUZIONE ANNOADATTAMENTO  FASCIAETAADATTAMENTO  NUMEROPIANI SPERFICIEAREATOTALE SPERFICIEAREALIBERA     VOLUME SPAZIDIDATTICI   AULAMAGNA       MENSA PALESTRAPISCINA SPAZIAMMINISTRATIVI SCUOLABUS TRASPORTIPUBBLICIURBANI TRASPORTIPUBBLICIINTERURBANI TRASPORTIFERROVIARI MEZZIPRIVATI TRASPORTODISABILI                                                                       Linea_finanziamento COMUNE FONTE Data_aggiornamento_lavori Data_inizio Data_fine ENTE_RICHIEDENTE TIPOLOGIA_ENTE_RICHIEDENTE   COD_PRINC OGGETTO_INTERVENTO INFO_AGGIUNTIVE  LATITUDINE  LONGITUDINE             TIPO_INTERVENTO STATO 
# ...

# %%
# cuneo JOIN tra CANTIERI e OPENCUP
print ("Iniziale: ",len(edifici_6_cn_cantieri), "  ", len(cup))
edifici_6_cn_cantieri_cup = pd.merge(edifici_6_cn_cantieri, cup,how='left',on='CUP',suffixes=('','_drop'))
edifici_6_cn_cantieri_cup = edifici_6_cn_cantieri_cup.drop([col for col in edifici_6_cn_cantieri_cup.columns if '_drop' in col],axis=1)
print ("Finale: ",len(edifici_6_cn_cantieri),"-",edifici_6_cn_cantieri_cup.CODICESCUOLA.nunique())
edifici_6_cn_cantieri_cup.to_csv("edifici_6_cn_cantieri_cup.csv", sep='|',index=False, header=True,  encoding='utf-8')
# Out:
# Iniziale:  950    1129591
# Finale:  950 - 786

# %%
# ITALIA JOIN tra CANTIERI e OPENCUP
print ("Iniziale: ",len(edifici_6_cantieri), "  ", len(cup))
edifici_6_cantieri_cup = pd.merge(edifici_6_cantieri, cup,how='left',on='CUP',suffixes=('','_drop'))
edifici_6_cantieri_cup = edifici_6_cantieri_cup.drop([col for col in edifici_6_cantieri_cup.columns if '_drop' in col],axis=1)
print ("Finale: ",len(edifici_6_cantieri),"-",edifici_6_cantieri_cup.CODICESCUOLA.nunique())
edifici_6_cantieri_cup = edifici_6_cantieri_cup.rename(columns=lambda x: x.strip())
edifici_6_cantieri_cup.to_csv("edifici_6_cantieri_cup.csv", sep='|',index=False, header=True,  encoding='utf-8')
# Out:
# Iniziale:  77559    1129591
# Finale:  77559 - 65503

# %%
edifici_6_cn_cantieri_cup.shape
# Out:
# (1006, 125)

# %%
edifici_6_cn_cantieri_cup.FASCIAETACOSTRUZIONE.value_counts()
# Out:
# Informazione assente     344
# tra il 1961 e il 1975    78
# tra il 1921 e il 1945    62
# tra il 1800 e il 1899    57
# dal 1976 in poi          50
# tra il 1946 e il 1960    47
# prima del 1800           42
# tra il 1900 e il 1920    33
# Name: FASCIAETACOSTRUZIONE, dtype: int64

# %%
edifici_6_cn_cantieri_cup.FASCIAETAADATTAMENTO.value_counts()
# Out:
# Informazione assente     599
# tra il 1946 e il 1975    50
# Dal 1976 in poi          42
# prima del 1945           22
# Name: FASCIAETAADATTAMENTO, dtype: int64

# %%
edifici_6_cn_cantieri_cup.shape()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b2f5e4726afb> in <module>()
# ----> 1 edifici_6_cn_cantieri_cup.shape()
#
# NameError: name 'edifici_6_cn_cantieri_cup' is not defined

# %% [markdown]
# ### Numeri di edifici per provincia --> aggregare per provincia

# %%
#seziono solo sulle scuole con STATO PROGETTO: ATTIVO
#componenti_strumenti.loc[componenti_strumenti['COR'] == "36527"]  
edifici_attivi = edifici.loc[edifici['STATOEDIFICIO']=="Attivo"]
edifici_attivi.shape
# Out:
# (50804, 11)

# %% [markdown]
# ### Quanti edifici e scuole ci sono in Italia?

# %%
print ("Numero di scuole: ",edifici_attivi.CODICESCUOLA.nunique())
# Out:
# Numero di scuole:  41753

# %%
print ("Numero di edifici: ",edifici.CODICEEDIFICIO.nunique())
# Out:
# Numero di edifici:  36093

# %% [markdown]
# ### Scuole con il link di scuole sicure

# %%
#hanno tutti il link ma con il parametro della scuola solo questo:
len(cup[cup.LINK_SCUOLE_SICURE.str.len() > 58])
# Out:
# 9819

# %%
cup.AREA_INTERVENTO.value_counts()
# Out:
# IMMOBILI                                 506602
# TRASPORTI                                318806
# AMBIENTE ED ENERGIA                      266243
# RICERCA, ITC, AREE PRODUTTIVE E ALTRO    37870
# Name: AREA_INTERVENTO, dtype: int64

# %%
cup.SOTTOSETTORE_INTERVENTO.value_counts()
# Out:
# STRADALI                                                                                          294810
# SOCIALI E SCOLASTICHE                                                                             159058
# ALTRE INFRASTRUTTURE SOCIALI                                                                      106123
# DIFESA DEL SUOLO                                                                                  87641
# RISORSE IDRICHE E ACQUE REFLUE                                                                    79778
# SPORT, SPETTACOLO E TEMPO LIBERO                                                                  59310
# PROTEZIONE, VALORIZZAZIONE E FRUIZIONE DELL'AMBIENTE                                              52504
# BENI CULTURALI                                                                                    52127
# ABITATIVE                                                                                         39867
# ...

# %%
cup.TIPOLOGIA_INTERVENTO.value_counts()
# Out:
# MANUTENZIONE STRAORDINARIA                                                                     506092
# NUOVA REALIZZAZIONE                                                                            231344
# MANUTENZIONE ORDINARIA                                                                         113956
# RISTRUTTURAZIONE (PER CAMBIO DI DESTINAZIONE D'USO)                                            88677
# ALTRO                                                                                          61613
# AMPLIAMENTO (COMPRESA SOPRAELEVAZIONE) O POTENZIAMENTO                                         40941
# RECUPERO                                                                                       40409
# RESTAURO                                                                                       33515
# MANUTENZIONE STRAORDINARIA CON EFFICIENTAMENTO ENERGETICO                                      4356
# ...

# %% [markdown]
# ### Filtro su Tipologie di intervento e Sottosettore
#
# Ci sono 4 **TIPOLOGIE DI INTERVENTO** specifiche:
#
# MANUTENZIONE STRAORDINARIA DI ADEGUAMENTO IMPIANTISTICA E O ANTINCENDIO                        342
# MANUTENZIONE STRAORDINARIA DI MIGLIORAMENTO SISMICO                                            150
# MANUTENZIONE STRAORDINARIA DI ADEGUAMENTO SISMICO                                              132
# MANUTENZIONE STRAORDINARIA PER ACCESSIBILITA' E ABBATTIMENTO DELLE BARRIERE ARCHITETTONICHE    114
#
# e un **SOTTOSETTORE di INTERVENTO** che ci interessa: SOCIALI E SCOLASTICHE

# %%
tipologie = ["MANUTENZIONE STRAORDINARIA DI ADEGUAMENTO IMPIANTISTICA E O ANTINCENDIO", 
             "MANUTENZIONE STRAORDINARIA DI MIGLIORAMENTO SISMICO",
             "MANUTENZIONE STRAORDINARIA DI ADEGUAMENTO SISMICO",
             "MANUTENZIONE STRAORDINARIA PER ACCESSIBILITA' E ABBATTIMENTO DELLE BARRIERE ARCHITETTONICHE"]
settori = ["SOCIALI E SCOLASTICHE"]
print ("CUP TOT:", len(cup))
cup_tipologia = cup[cup['TIPOLOGIA_INTERVENTO'].isin(tipologie)]
print ("CUP TIPOLOGIA ", len(cup_tipologia))
